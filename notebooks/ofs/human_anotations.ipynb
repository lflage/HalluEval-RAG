# %% [markdown]
# # Llama3.1 instruct and Human aggrement

# %%
def replace(a):
    """
    replaces original labeling with True for "S" (supported) or False for IR (irrelevant) or NS(not-supported)
    """
    if a == "IR":
        return False
    if a == "S":
        return True
    if a == "NS":
        return False

# %%
# Replacing original FactScore manual labels with machine labels i.e. IR, NS, S for True or False
# passing all atomic facts and decisions to a list of {"text": str, "label": bool}
import json
from pprint import pprint

human_evals = []
no_annotations = []
count = 0
with open('../FactScore/data/labeled/InstructGPT.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        i = json.loads(line)
        if i['annotations'] is None:
            # print(i["topic"])
            continue
        for a in i['annotations']:
            if not a['is-relevant']:
                continue
            for fact in a["human-atomic-facts"]:
                human_evals.append({"text": fact["text"],
                                    "label": replace(fact.get("label")) })
                
print(len(human_evals))
print(human_evals[0])
# Out:
# 4726
# {'text': 'Doug Sheehan is an American.', 'label': True}

# %%
for evals in human_evals:
    try:
        assert evals["label"] in {True, False}
    except:
        print(evals["label"])

# %%
# Load Machine annotated data
# Pass llama3.1 decisionas as list of {"atom": str, "is_supported": bool"}
llama_evals = []
path = "/home/lucas_dfki/Documentos/repos/HalluEval-RAG/data/afv_json/InstructGPT_factscore_output_human-atomic-facts.json"
with open(path, 'r', encoding='utf-8') as jsl:
        llama_evals = json.load(jsl)
        
llamas = [atom for doc in llama_evals["decisions"] for atom in doc]
print(llamas[0])
print(len(llamas))
# Out:
# {'atom': 'Doug Sheehan is an American.', 'is_supported': True}
# 4726

# %%
# Sanity checks
assert len(llamas) == len(human_evals)
for machine, human in zip(llamas, human_evals):
    assert machine["atom"] == human["text"]
#    if machine["is_supported"] != human["label"]:
#        print(machine)
#        print(human)
# Out:
# {'atom': 'Knots Landing is a drama series.', 'is_supported': True}
# {'text': 'Knots Landing is a drama series.', 'label': False}
# {'atom': 'He has appeared in films.', 'is_supported': False}
# {'text': 'He has appeared in films.', 'label': True}
# {'atom': 'The Bronx is in New York.', 'is_supported': True}
# {'text': 'The Bronx is in New York.', 'label': False}
# {'atom': 'This Time was released in 1997.', 'is_supported': False}
# {'text': 'This Time was released in 1997.', 'label': True}
# {'atom': 'She has had guest appearances on New York Undercover.', 'is_supported': True}
# {'text': 'She has had guest appearances on New York Undercover.', 'label': False}
# {'atom': 'His work includes directing feature films.', 'is_supported': False}
# {'text': 'His work includes directing feature films.', 'label': True}
# {'atom': 'His work includes producing feature films.', 'is_supported': False}
# {'text': 'His work includes producing feature films.', 'label': True}
# {'atom': 'He has written and/or produced content for CBS.', 'is_supported': True}
# {'text': 'He has written and/or produced content for CBS.', 'label': False}
# {'atom': 'He has gone on to appear in a number of feature films.', 'is_supported': False}
# {'text': 'He has gone on to appear in a number of feature films.', 'label': True}
# {'atom': 'Chaim Malinowitz is an author.', 'is_supported': False}
# {'text': 'Chaim Malinowitz is an author.', 'label': True}
# {'atom': 'He has been featured in The Times of Israel.', 'is_supported': True}
# {'text': 'He has been featured in The Times of Israel.', 'label': False}
# {'atom': 'She moved to television.', 'is_supported': False}
# {'text': 'She moved to television.', 'label': True}
# {'atom': 'She moved to film.', 'is_supported': False}
# {'text': 'She moved to film.', 'label': True}
# {'atom': 'She made the move in the late 1960s.', 'is_supported': False}
# {'text': 'She made the move in the late 1960s.', 'label': True}
# {'atom': 'She is married.', 'is_supported': False}
# {'text': 'She is married.', 'label': True}
# {'atom': 'Lees Knowles is a writer.', 'is_supported': True}
# {'text': 'Lees Knowles is a writer.', 'label': False}
# {'atom': 'He was a close ally of Emperor Trajan.', 'is_supported': False}
# {'text': 'He was a close ally of Emperor Trajan.', 'label': True}
# {'atom': 'He worked on many projects.', 'is_supported': True}
# {'text': 'He worked on many projects.', 'label': False}
# {'atom': 'He worked on projects in the UK.', 'is_supported': True}
# {'text': 'He worked on projects in the UK.', 'label': False}
# {'atom': 'He has held positions in the Italian cultural heritage sector.', 'is_supported': False}
# {'text': 'He has held positions in the Italian cultural heritage sector.', 'label': True}
# {'atom': 'Joeri Adams is a professional cyclist.', 'is_supported': True}
# {'text': 'Joeri Adams is a professional cyclist.', 'label': False}
# {'atom': "She earned a master's degree.", 'is_supported': False}
# {'text': "She earned a master's degree.", 'label': True}
# {'atom': 'She earned her degree in 1979.', 'is_supported': False}
# {'text': 'She earned her degree in 1979.', 'label': True}
# {'atom': 'She has held various positions within the Mexican government.', 'is_supported': True}
# {'text': 'She has held various positions within the Mexican government.', 'label': False}
# {'atom': 'He was signed by the San Diego Padres.', 'is_supported': True}
# {'text': 'He was signed by the San Diego Padres.', 'label': False}
# {'atom': 'He was signed in 2011.', 'is_supported': False}
# {'text': 'He was signed in 2011.', 'label': True}
# {'atom': 'He spent four seasons in the minor leagues.', 'is_supported': False}
# {'text': 'He spent four seasons in the minor leagues.', 'label': True}
# {'atom': 'She has since gone on to win several medals.', 'is_supported': False}
# {'text': 'She has since gone on to win several medals.', 'label': True}
# {'atom': 'She has since gone on to win medals in international competitions.', 'is_supported': False}
# {'text': 'She has since gone on to win medals in international competitions.', 'label': True}
# {'atom': 'Fernando Luiz Rosa is a Brazilian.', 'is_supported': False}
# {'text': 'Fernando Luiz Rosa is a Brazilian.', 'label': True}
# {'atom': 'Fernando Luiz Rosa is commonly known as Fernando.', 'is_supported': False}
# {'text': 'Fernando Luiz Rosa is commonly known as Fernando.', 'label': True}
# {'atom': 'Fernando Luiz Rosa is a professional footballer.', 'is_supported': False}
# {'text': 'Fernando Luiz Rosa is a professional footballer.', 'label': True}
# {'atom': 'The Liar and His Lover is a television drama.', 'is_supported': True}
# {'text': 'The Liar and His Lover is a television drama.', 'label': False}
# {'atom': 'He is best known for his appearance in When the Devil Calls Your Name.', 'is_supported': False}
# {'text': 'He is best known for his appearance in When the Devil Calls Your Name.', 'label': True}
# {'atom': 'When the Devil Calls Your Name is a television drama.', 'is_supported': True}
# {'text': 'When the Devil Calls Your Name is a television drama.', 'label': False}
# {'atom': 'He has appeared in several web dramas.', 'is_supported': False}
# {'text': 'He has appeared in several web dramas.', 'label': True}
# {'atom': 'He has received multiple awards for his acting.', 'is_supported': False}
# {'text': 'He has received multiple awards for his acting.', 'label': True}
# {'atom': 'Lily Branscombe is an artist.', 'is_supported': False}
# {'text': 'Lily Branscombe is an artist.', 'label': True}
# {'atom': 'Lily Branscombe is successful.', 'is_supported': True}
# {'text': 'Lily Branscombe is successful.', 'label': False}
# {'atom': 'Ko Itakura is Japanese.', 'is_supported': True}
# {'text': 'Ko Itakura is Japanese.', 'label': False}
# {'atom': 'He has represented India in several international competitions.', 'is_supported': False}
# {'text': 'He has represented India in several international competitions.', 'label': True}
# {'atom': 'Besant Ravi is renowned.', 'is_supported': True}
# {'text': 'Besant Ravi is renowned.', 'label': False}
# {'atom': 'He is best known for his roles in films.', 'is_supported': False}
# {'text': 'He is best known for his roles in films.', 'label': True}
# {'atom': 'He joined the South Korean Foreign Ministry.', 'is_supported': False}
# {'text': 'He joined the South Korean Foreign Ministry.', 'label': True}
# {'atom': 'He occupied a number of posts.', 'is_supported': False}
# {'text': 'He occupied a number of posts.', 'label': True}
# {'atom': 'He served as Ambassador from 2001.', 'is_supported': True}
# {'text': 'He served as Ambassador from 2001.', 'label': False}
# {'atom': 'Michael Valpy is an academic.', 'is_supported': False}
# {'text': 'Michael Valpy is an academic.', 'label': True}
# {'atom': 'He is a former columnist.', 'is_supported': False}
# {'text': 'He is a former columnist.', 'label': True}
# {'atom': 'He has written about social issues.', 'is_supported': True}
# {'text': 'He has written about social issues.', 'label': False}
# {'atom': 'He has written about economic issues.', 'is_supported': True}
# {'text': 'He has written about economic issues.', 'label': False}
# {'atom': 'He has written about issues abroad.', 'is_supported': True}
# {'text': 'He has written about issues abroad.', 'label': False}
# {'atom': 'Valpy has served as a lecturer at the University of Toronto.', 'is_supported': True}
# {'text': 'Valpy has served as a lecturer at the University of Toronto.', 'label': False}
# {'atom': "He is a recipient of the Queen's Diamond Jubilee medal.", 'is_supported': True}
# {'text': "He is a recipient of the Queen's Diamond Jubilee medal.", 'label': False}
# {'atom': 'He is currently a Senior Fellow.', 'is_supported': False}
# {'text': 'He is currently a Senior Fellow.', 'label': True}
# {'atom': 'Alma Katsu writes historical fiction.', 'is_supported': False}
# {'text': 'Alma Katsu writes historical fiction.', 'label': True}
# {'atom': 'The horror novel is called The Taker Trilogy.', 'is_supported': True}
# {'text': 'The horror novel is called The Taker Trilogy.', 'label': False}
# {'atom': 'The Hunger is a novel.', 'is_supported': False}
# {'text': 'The Hunger is a novel.', 'label': True}
# {'atom': 'She was born in the United States.', 'is_supported': False}
# {'text': 'She was born in the United States.', 'label': True}
# {'atom': 'The degree was in literature.', 'is_supported': False}
# {'text': 'The degree was in literature.', 'label': True}
# {'atom': 'He was a right-handed pitcher.', 'is_supported': False}
# {'text': 'He was a right-handed pitcher.', 'label': True}
# {'atom': 'He played for the Giants over the course of three seasons.', 'is_supported': False}
# {'text': 'He played for the Giants over the course of three seasons.', 'label': True}
# {'atom': 'He was limited by injuries.', 'is_supported': False}
# {'text': 'He was limited by injuries.', 'label': True}
# {'atom': 'He never returned to the majors.', 'is_supported': False}
# {'text': 'He never returned to the majors.', 'label': True}
# {'atom': 'Mike often expresses his opinions.', 'is_supported': False}
# {'text': 'Mike often expresses his opinions.', 'label': True}
# {'atom': 'Mike often expresses his opinions on current events.', 'is_supported': False}
# {'text': 'Mike often expresses his opinions on current events.', 'label': True}
# {'atom': 'Mike often expresses his opinions on politics.', 'is_supported': False}
# {'text': 'Mike often expresses his opinions on politics.', 'label': True}
# {'atom': 'He regularly talks about the Browns.', 'is_supported': False}
# {'text': 'He regularly talks about the Browns.', 'label': True}
# {'atom': 'Mike is in radio.', 'is_supported': False}
# {'text': 'Mike is in radio.', 'label': True}
# {'atom': 'He played college baseball.', 'is_supported': False}
# {'text': 'He played college baseball.', 'label': True}
# {'atom': 'Carlos Alfonso is American.', 'is_supported': False}
# {'text': 'Carlos Alfonso is American.', 'label': True}
# {'atom': 'He immigrated to the United States.', 'is_supported': False}
# {'text': 'He immigrated to the United States.', 'label': True}
# {'atom': 'He is best known for his work on religion.', 'is_supported': False}
# {'text': 'He is best known for his work on religion.', 'label': True}
# {'atom': 'He is an expert on the anthropology of religion.', 'is_supported': False}
# {'text': 'He is an expert on the anthropology of religion.', 'label': True}
# {'atom': 'His research focuses on the study of popular religion in Latin America.', 'is_supported': False}
# {'text': 'His research focuses on the study of popular religion in Latin America.', 'label': True}
# {'atom': 'He has published numerous essays.', 'is_supported': False}
# {'text': 'He has published numerous essays.', 'label': True}
# {'atom': 'He has published numerous books.', 'is_supported': False}
# {'text': 'He has published numerous books.', 'label': True}
# {'atom': 'Prince Rivers is an American.', 'is_supported': False}
# {'text': 'Prince Rivers is an American.', 'label': True}
# {'atom': 'Bella Akhmadulina was a novelist.', 'is_supported': False}
# {'text': 'Bella Akhmadulina was a novelist.', 'label': True}
# {'atom': 'Her mother was Russian.', 'is_supported': False}
# {'text': 'Her mother was Russian.', 'label': True}
# {'atom': 'She grew up in Moscow.', 'is_supported': False}
# {'text': 'She grew up in Moscow.', 'label': True}
# {'atom': 'Her peerage was granted in 2007.', 'is_supported': False}
# {'text': 'Her peerage was granted in 2007.', 'label': True}
# {'atom': 'Kourosh has a degree.', 'is_supported': False}
# {'text': 'Kourosh has a degree.', 'label': True}
# {'atom': 'Daniel Charles is a professional writer.', 'is_supported': False}
# {'text': 'Daniel Charles is a professional writer.', 'label': True}
# {'atom': 'She wrote for Proceso.', 'is_supported': False}
# {'text': 'She wrote for Proceso.', 'label': True}
# {'atom': 'Proceso is a magazine.', 'is_supported': False}
# {'text': 'Proceso is a magazine.', 'label': True}
# {'atom': "Proceso is one of Mexico's foremost investigative media outlets.", 'is_supported': True}
# {'text': "Proceso is one of Mexico's foremost investigative media outlets.", 'label': False}
# {'atom': 'She was found in 2012.', 'is_supported': False}
# {'text': 'She was found in 2012.', 'label': True}
# {'atom': 'She is believed to have been murdered.', 'is_supported': False}
# {'text': 'She is believed to have been murdered.', 'label': True}
# {'atom': 'Her death led to calls for justice in her case.', 'is_supported': True}
# {'text': 'Her death led to calls for justice in her case.', 'label': False}
# {'atom': 'She is an advocate for the rights of FGM survivors.', 'is_supported': True}
# {'text': 'She is an advocate for the rights of FGM survivors.', 'label': False}
# {'atom': 'She is an outspoken advocate.', 'is_supported': False}
# {'text': 'She is an outspoken advocate.', 'label': True}
# {'atom': 'She campaigns for the abolition of FGM worldwide.', 'is_supported': True}
# {'text': 'She campaigns for the abolition of FGM worldwide.', 'label': False}
# {'atom': 'She has written a memoir.', 'is_supported': False}
# {'text': 'She has written a memoir.', 'label': True}
# {'atom': 'Corrada del Río was known for his fiscal conservatism.', 'is_supported': True}
# {'text': 'Corrada del Río was known for his fiscal conservatism.', 'label': False}
# {'atom': 'He was an advocate for Puerto Rican self-determination.', 'is_supported': True}
# {'text': 'He was an advocate for Puerto Rican self-determination.', 'label': False}
# {'atom': "He supported Puerto Rico's autonomy within the United States.", 'is_supported': True}
# {'text': "He supported Puerto Rico's autonomy within the United States.", 'label': False}
# {'atom': "He was a supporter of Puerto Rico's cultural heritage.", 'is_supported': True}
# {'text': "He was a supporter of Puerto Rico's cultural heritage.", 'label': False}
# {'atom': "He was a supporter of Puerto Rico's linguistic heritage.", 'is_supported': True}
# {'text': "He was a supporter of Puerto Rico's linguistic heritage.", 'label': False}
# {'atom': 'He is best known for his roles in comedy films.', 'is_supported': False}
# {'text': 'He is best known for his roles in comedy films.', 'label': True}
# {'atom': 'He is best known for his roles in television series.', 'is_supported': False}
# {'text': 'He is best known for his roles in television series.', 'label': True}
# {'atom': 'Since he began his career, he has gone on to star in numerous films.', 'is_supported': False}
# {'text': 'Since he began his career, he has gone on to star in numerous films.', 'label': True}
# {'atom': 'Since he began his career, he has gone on to star in numerous TV series.', 'is_supported': False}
# {'text': 'Since he began his career, he has gone on to star in numerous TV series.', 'label': True}
# {'atom': 'Since he began his career, he has gone on to star in numerous stage plays.', 'is_supported': False}
# {'text': 'Since he began his career, he has gone on to star in numerous stage plays.', 'label': True}
# {'atom': 'He is a popular sketch comedian.', 'is_supported': True}
# {'text': 'He is a popular sketch comedian.', 'label': False}
# {'atom': 'The awards were for his work.', 'is_supported': True}
# {'text': 'The awards were for his work.', 'label': False}
# {'atom': 'He is known for his exaggerated style.', 'is_supported': True}
# {'text': 'He is known for his exaggerated style.', 'label': False}
# {'atom': 'Lagos is in Nigeria.', 'is_supported': True}
# {'text': 'Lagos is in Nigeria.', 'label': False}
# {'atom': 'Malcolm Hedding is an author.', 'is_supported': False}
# {'text': 'Malcolm Hedding is an author.', 'label': True}
# {'atom': 'Malcolm Hedding is a speaker.', 'is_supported': True}
# {'text': 'Malcolm Hedding is a speaker.', 'label': False}
# {'atom': 'He is a prolific writer.', 'is_supported': False}
# {'text': 'He is a prolific writer.', 'label': True}
# {'atom': 'Johannesburg is in South Africa.', 'is_supported': True}
# {'text': 'Johannesburg is in South Africa.', 'label': False}
# {'atom': 'He was an outspoken critic.', 'is_supported': False}
# {'text': 'He was an outspoken critic.', 'label': True}
# {'atom': 'He lived in exile in the United States.', 'is_supported': False}
# {'text': 'He lived in exile in the United States.', 'label': True}
# {'atom': 'He published books of non-fiction.', 'is_supported': False}
# {'text': 'He published books of non-fiction.', 'label': True}
# {'atom': 'Mating Birds is a book.', 'is_supported': False}
# {'text': 'Mating Birds is a book.', 'label': True}
# {'atom': 'He exhibited his work in numerous international exhibitions.', 'is_supported': False}
# {'text': 'He exhibited his work in numerous international exhibitions.', 'label': True}
# {'atom': "Fonseca's work combines simple geometric forms to create dynamic compositions.", 'is_supported': True}
# {'text': "Fonseca's work combines simple geometric forms to create dynamic compositions.", 'label': False}
# {'atom': 'Carl Andre is a minimalist sculptor.', 'is_supported': False}
# {'text': 'Carl Andre is a minimalist sculptor.', 'label': True}
# {'atom': 'Dan Flavin is a minimalist sculptor.', 'is_supported': False}
# {'text': 'Dan Flavin is a minimalist sculptor.', 'label': True}
# {'atom': 'Matthew Tukaki is from New Zealand.', 'is_supported': True}
# {'text': 'Matthew Tukaki is from New Zealand.', 'label': False}
# {'atom': 'He is the Executive Chairman.', 'is_supported': False}
# {'text': 'He is the Executive Chairman.', 'label': True}
# {'atom': 'He is the Executive Director of the New Zealand Maori Council.', 'is_supported': False}
# {'text': 'He is the Executive Director of the New Zealand Maori Council.', 'label': True}
# {'atom': 'He is a passionate advocate for Maori communities.', 'is_supported': False}
# {'text': 'He is a passionate advocate for Maori communities.', 'label': True}
# {'atom': 'She has appeared in numerous television series.', 'is_supported': True}
# {'text': 'She has appeared in numerous television series.', 'label': False}
# {'atom': 'He has been a Member of Parliament since 2007.', 'is_supported': False}
# {'text': 'He has been a Member of Parliament since 2007.', 'label': True}
# {'atom': 'Neumann completed a Bachelor of Arts degree at the University of Queensland.', 'is_supported': False}
# {'text': 'Neumann completed a Bachelor of Arts degree at the University of Queensland.', 'label': True}
# {'atom': 'He practiced as a lawyer.', 'is_supported': False}
# {'text': 'He practiced as a lawyer.', 'label': True}
# {'atom': 'He was a lawyer in Queensland.', 'is_supported': True}
# {'text': 'He was a lawyer in Queensland.', 'label': False}
# {'atom': 'Neumann was re-elected four times.', 'is_supported': True}
# {'text': 'Neumann was re-elected four times.', 'label': False}
# {'atom': 'He was appointed in 2013.', 'is_supported': True}
# {'text': 'He was appointed in 2013.', 'label': False}
# {'atom': 'Jagan Mohan Reddy is an Indian.', 'is_supported': False}
# {'text': 'Jagan Mohan Reddy is an Indian.', 'label': True}
# {'atom': 'Kakru has held several prestigious positions.', 'is_supported': False}
# {'text': 'Kakru has held several prestigious positions.', 'label': True}
# {'atom': 'Ben Lummis is a songwriter.', 'is_supported': False}
# {'text': 'Ben Lummis is a songwriter.', 'label': True}
# {'atom': 'He has released Ben Lummis.', 'is_supported': True}
# {'text': 'He has released Ben Lummis.', 'label': False}
# {'atom': 'Ben Lummis reached multi-platinum status in his native country.', 'is_supported': False}
# {'text': 'Ben Lummis reached multi-platinum status in his native country.', 'label': True}
# {'atom': 'She is best known for her album “Try Me Again”.', 'is_supported': False}
# {'text': 'She is best known for her album “Try Me Again”.', 'label': True}
# {'atom': 'She has earned multiple Grammy nominations.', 'is_supported': False}
# {'text': 'She has earned multiple Grammy nominations.', 'label': True}
# {'atom': 'She has performed with renowned artists.', 'is_supported': False}
# {'text': 'She has performed with renowned artists.', 'label': True}
# {'atom': 'Stevie Wonder is a renowned artist.', 'is_supported': False}
# {'text': 'Stevie Wonder is a renowned artist.', 'label': True}
# {'atom': 'She has performed with Stevie Wonder.', 'is_supported': False}
# {'text': 'She has performed with Stevie Wonder.', 'label': True}
# {'atom': 'Virginia Valli worked primarily in silent films.', 'is_supported': False}
# {'text': 'Virginia Valli worked primarily in silent films.', 'label': True}
# {'atom': 'She was born in Chicago.', 'is_supported': False}
# {'text': 'She was born in Chicago.', 'label': True}
# {'atom': 'Valli returned to the stage.', 'is_supported': True}
# {'text': 'Valli returned to the stage.', 'label': False}
# {'atom': 'Valli appeared in several Broadway productions.', 'is_supported': True}
# {'text': 'Valli appeared in several Broadway productions.', 'label': False}
# {'atom': 'She died in California.', 'is_supported': False}
# {'text': 'She died in California.', 'label': True}
# {'atom': 'Los Angeles is in California.', 'is_supported': True}
# {'text': 'Los Angeles is in California.', 'label': False}
# {'atom': 'He is a professor of anatomy.', 'is_supported': False}
# {'text': 'He is a professor of anatomy.', 'label': True}
# {'atom': 'He has written books on the topics of gender identity.', 'is_supported': False}
# {'text': 'He has written books on the topics of gender identity.', 'label': True}
# {'atom': 'He has written articles on the topics of gender identity.', 'is_supported': False}
# {'text': 'He has written articles on the topics of gender identity.', 'label': True}
# {'atom': 'He has written books on the topics of homosexuality.', 'is_supported': False}
# {'text': 'He has written books on the topics of homosexuality.', 'label': True}
# {'atom': 'He has written articles on the topics of homosexuality.', 'is_supported': False}
# {'text': 'He has written articles on the topics of homosexuality.', 'label': True}
# {'atom': 'He has written books 0n the topics of transgenderism.', 'is_supported': False}
# {'text': 'He has written books 0n the topics of transgenderism.', 'label': True}
# {'atom': 'He has written articles on the topics of transgenderism.', 'is_supported': False}
# {'text': 'He has written articles on the topics of transgenderism.', 'label': True}
# {'atom': 'He has written books on the topics of sexual health.', 'is_supported': False}
# {'text': 'He has written books on the topics of sexual health.', 'label': True}
# {'atom': 'He has written articles on the topics of sexual health.', 'is_supported': False}
# {'text': 'He has written articles on the topics of sexual health.', 'label': True}
# {'atom': 'He has conducted research.', 'is_supported': False}
# {'text': 'He has conducted research.', 'label': True}
# {'atom': 'Travis Oliphant is the CEO of Quansight.', 'is_supported': True}
# {'text': 'Travis Oliphant is the CEO of Quansight.', 'label': False}
# {'atom': 'Travis Oliphant is the founder of Quansight.', 'is_supported': True}
# {'text': 'Travis Oliphant is the founder of Quansight.', 'label': False}
# {'atom': 'Quansight is a data science company.', 'is_supported': True}
# {'text': 'Quansight is a data science company.', 'label': False}
# {'atom': 'He is a serial entrepreneur.', 'is_supported': False}
# {'text': 'He is a serial entrepreneur.', 'label': True}
# {'atom': 'He has founded companies in the data science space.', 'is_supported': True}
# {'text': 'He has founded companies in the data science space.', 'label': False}
# {'atom': 'He was the co-founder of Continuum Analytics.', 'is_supported': True}
# {'text': 'He was the co-founder of Continuum Analytics.', 'label': False}
# {'atom': 'Continuum Analytics is a Python-based platform.', 'is_supported': True}
# {'text': 'Continuum Analytics is a Python-based platform.', 'label': False}
# {'atom': 'He is a member of the NumPy core development team.', 'is_supported': True}
# {'text': 'He is a member of the NumPy core development team.', 'label': False}
# {'atom': 'He holds a PhD.', 'is_supported': False}
# {'text': 'He holds a PhD.', 'label': True}
# {'atom': 'He experienced numerous personal struggles.', 'is_supported': False}
# {'text': 'He experienced numerous personal struggles.', 'label': True}
# {'atom': 'He experienced numerous financial struggles.', 'is_supported': False}
# {'text': 'He experienced numerous financial struggles.', 'label': True}
# {'atom': 'He was unable to manage his newfound wealth.', 'is_supported': False}
# {'text': 'He was unable to manage his newfound wealth.', 'label': True}
# {'atom': 'He was involved in legal disputes.', 'is_supported': False}
# {'text': 'He was involved in legal disputes.', 'label': True}
# {'atom': 'He was involved in a criminal trial.', 'is_supported': False}
# {'text': 'He was involved in a criminal trial.', 'label': True}
# {'atom': 'Featherstone was born in Leominster.', 'is_supported': False}
# {'text': 'Featherstone was born in Leominster.', 'label': True}
# {'atom': 'Leominster is in Massachusetts.', 'is_supported': False}
# {'text': 'Leominster is in Massachusetts.', 'label': True}
# {'atom': 'His career began in 1956.', 'is_supported': False}
# {'text': 'His career began in 1956.', 'label': True}
# {'atom': 'His career began when he was hired.', 'is_supported': False}
# {'text': 'His career began when he was hired.', 'label': True}
# {'atom': 'Union Products is a small plastics company.', 'is_supported': False}
# {'text': 'Union Products is a small plastics company.', 'label': True}
# {'atom': 'Union Products is located in Leominster.', 'is_supported': False}
# {'text': 'Union Products is located in Leominster.', 'label': True}
# {'atom': 'Featherstone worked for Union Products for the rest of his career.', 'is_supported': False}
# {'text': 'Featherstone worked for Union Products for the rest of his career.', 'label': True}
# {'atom': 'Rob Furlong is a sniper.', 'is_supported': True}
# {'text': 'Rob Furlong is a sniper.', 'label': False}
# {'atom': 'He is best known for holding a record.', 'is_supported': False}
# {'text': 'He is best known for holding a record.', 'label': True}
# {'atom': 'The longest confirmed kill shot in military history is 2,430 metres.', 'is_supported': False}
# {'text': 'The longest confirmed kill shot in military history is 2,430 metres.', 'label': True}
# {'atom': 'The longest confirmed kill shot in military history is 2,657 yards.', 'is_supported': False}
# {'text': 'The longest confirmed kill shot in military history is 2,657 yards.', 'label': True}
# {'atom': 'He was deployed in 2002.', 'is_supported': False}
# {'text': 'He was deployed in 2002.', 'label': True}
# {'atom': 'They were high-value targets.', 'is_supported': True}
# {'text': 'They were high-value targets.', 'label': False}
# {'atom': 'He is considered one of the most successful snipers in modern history.', 'is_supported': True}
# {'text': 'He is considered one of the most successful snipers in modern history.', 'label': False}
# {'atom': 'Fran Unsworth is the Director of BBC Current Affairs.', 'is_supported': True}
# {'text': 'Fran Unsworth is the Director of BBC Current Affairs.', 'label': False}
# {'atom': 'She has held a variety of roles at the BBC.', 'is_supported': False}
# {'text': 'She has held a variety of roles at the BBC.', 'label': True}
# {'atom': 'Robert Smith is the chairman of several companies.', 'is_supported': False}
# {'text': 'Robert Smith is the chairman of several companies.', 'label': True}
# {'atom': 'He has served as a non-executive director of several companies.', 'is_supported': False}
# {'text': 'He has served as a non-executive director of several companies.', 'label': True}
# {'atom': 'The Royal Bank of Scotland is a company.', 'is_supported': True}
# {'text': 'The Royal Bank of Scotland is a company.', 'label': False}
# {'atom': 'He has served as a non-executive director of the Royal Bank of Scotland.', 'is_supported': True}
# {'text': 'He has served as a non-executive director of the Royal Bank of Scotland.', 'label': False}
# {'atom': 'He was made a life peer.', 'is_supported': False}
# {'text': 'He was made a life peer.', 'label': True}
# {'atom': 'He was an important figure in the development of organ music.', 'is_supported': False}
# {'text': 'He was an important figure in the development of organ music.', 'label': True}
# {'atom': 'He was a major influence on the French organ school.', 'is_supported': False}
# {'text': 'He was a major influence on the French organ school.', 'label': True}
# {'atom': 'He was one of the first organists to accompany choirs.', 'is_supported': True}
# {'text': 'He was one of the first organists to accompany choirs.', 'label': False}
# {'atom': 'He was one of the first organists to accompany orchestras.', 'is_supported': True}
# {'text': 'He was one of the first organists to accompany orchestras.', 'label': False}
# {'atom': 'He wrote many organ works.', 'is_supported': False}
# {'text': 'He wrote many organ works.', 'label': True}
# {'atom': 'He wrote numerous chamber works.', 'is_supported': False}
# {'text': 'He wrote numerous chamber works.', 'label': True}
# {'atom': 'The books were on the subject of organ music.', 'is_supported': False}
# {'text': 'The books were on the subject of organ music.', 'label': True}
# {'atom': 'He was in the cabinet in the early 1990s.', 'is_supported': False}
# {'text': 'He was in the cabinet in the early 1990s.', 'label': True}
# {'atom': 'He was as Secretary of State for Health from 1990-92.', 'is_supported': False}
# {'text': 'He was as Secretary of State for Health from 1990-92.', 'label': True}
# {'atom': 'He was a senior advisor to Prime Minister John Major.', 'is_supported': True}
# {'text': 'He was a senior advisor to Prime Minister John Major.', 'label': False}
# {'atom': 'He left Parliament.', 'is_supported': True}
# {'text': 'He left Parliament.', 'label': False}
# {'atom': 'He is a member of the Conservative Party.', 'is_supported': False}
# {'text': 'He is a member of the Conservative Party.', 'label': True}
# {'atom': 'He served as Chancellor of the Exchequer.', 'is_supported': False}
# {'text': 'He served as Chancellor of the Exchequer.', 'label': True}
# {'atom': 'He was the Shadow Chancellor of the Exchequer.', 'is_supported': True}
# {'text': 'He was the Shadow Chancellor of the Exchequer.', 'label': False}
# {'atom': 'He has written books on philosophy.', 'is_supported': True}
# {'text': 'He has written books on philosophy.', 'label': False}
# {'atom': 'Terence Blacker is a journalist.', 'is_supported': False}
# {'text': 'Terence Blacker is a journalist.', 'label': True}
# {'atom': 'Terence Blacker is a publisher.', 'is_supported': False}
# {'text': 'Terence Blacker is a publisher.', 'label': True}
# {'atom': 'He competed in 2013.', 'is_supported': True}
# {'text': 'He competed in 2013.', 'label': False}
# {'atom': 'He moved to the British GT4 Championship.', 'is_supported': False}
# {'text': 'He moved to the British GT4 Championship.', 'label': True}
# {'atom': 'She is one of the only female referees to have officiated at the highest level of the English game.', 'is_supported': True}
# {'text': 'She is one of the only female referees to have officiated at the highest level of the English game.', 'label': False}
# {'atom': 'She was appointed to the Football League in 2010.', 'is_supported': True}
# {'text': 'She was appointed to the Football League in 2010.', 'label': False}
# {'atom': 'She has refereed international matches.', 'is_supported': False}
# {'text': 'She has refereed international matches.', 'label': True}
# {'atom': 'He has managed clubs in Italy.', 'is_supported': False}
# {'text': 'He has managed clubs in Italy.', 'label': True}
# {'atom': 'He has managed clubs in Parma.', 'is_supported': False}
# {'text': 'He has managed clubs in Parma.', 'label': True}
# {'atom': 'He has managed clubs in Bologna.', 'is_supported': False}
# {'text': 'He has managed clubs in Bologna.', 'label': True}
# {'atom': 'Bologna is in Italy.', 'is_supported': False}
# {'text': 'Bologna is in Italy.', 'label': True}
# {'atom': 'He has managed clubs in Empoli.', 'is_supported': False}
# {'text': 'He has managed clubs in Empoli.', 'label': True}
# {'atom': 'Empoli is in Italy.', 'is_supported': False}
# {'text': 'Empoli is in Italy.', 'label': True}
# {'atom': 'He has gone on to manage a string of Italian clubs.', 'is_supported': False}
# {'text': 'He has gone on to manage a string of Italian clubs.', 'label': True}
# {'atom': 'Bologna is an Italian club.', 'is_supported': False}
# {'text': 'Bologna is an Italian club.', 'label': True}
# {'atom': 'The clubs he has managed include Empoli.', 'is_supported': False}
# {'text': 'The clubs he has managed include Empoli.', 'label': True}
# {'atom': 'Kisser has played a variety of styles.', 'is_supported': False}
# {'text': 'Kisser has played a variety of styles.', 'label': True}
# {'atom': 'Thrash metal is a style.', 'is_supported': False}
# {'text': 'Thrash metal is a style.', 'label': True}
# {'atom': 'Groove metal is a style.', 'is_supported': False}
# {'text': 'Groove metal is a style.', 'label': True}
# {'atom': 'He is an active solo artist.', 'is_supported': False}
# {'text': 'He is an active solo artist.', 'label': True}
# {'atom': 'He has released four studio albums.', 'is_supported': True}
# {'text': 'He has released four studio albums.', 'label': False}
# {'atom': 'Kisser has a musical career.', 'is_supported': True}
# {'text': 'Kisser has a musical career.', 'label': False}
# {'atom': 'She is best known for her role in Floricienta.', 'is_supported': False}
# {'text': 'She is best known for her role in Floricienta.', 'label': True}
# {'atom': 'Floricienta is a series.', 'is_supported': False}
# {'text': 'Floricienta is a series.', 'label': True}
# {'atom': 'He is known for his creative style of play.', 'is_supported': True}
# {'text': 'He is known for his creative style of play.', 'label': False}
# {'atom': 'He has been capped by Brazil.', 'is_supported': False}
# {'text': 'He has been capped by Brazil.', 'label': True}
# {'atom': 'He has been capped at the Under-20 level.', 'is_supported': False}
# {'text': 'He has been capped at the Under-20 level.', 'label': True}
# {'atom': 'He served until July 2008.', 'is_supported': False}
# {'text': 'He served until July 2008.', 'label': True}
# {'atom': 'He served in Buenos Aires.', 'is_supported': True}
# {'text': 'He served in Buenos Aires.', 'label': False}
# {'atom': 'He worked from 2003 to 2007.', 'is_supported': False}
# {'text': 'He worked from 2003 to 2007.', 'label': True}
# {'atom': 'He worked as an independent consultant.', 'is_supported': False}
# {'text': 'He worked as an independent consultant.', 'label': True}
# {'atom': 'He worked for national companies.', 'is_supported': True}
# {'text': 'He worked for national companies.', 'label': False}
# {'atom': 'Lousteau pushed for a new exchange rate system.', 'is_supported': True}
# {'text': 'Lousteau pushed for a new exchange rate system.', 'label': False}
# {'atom': 'He has served at several universities.', 'is_supported': True}
# {'text': 'He has served at several universities.', 'label': False}
# {'atom': 'He has served at the University of San Andrés.', 'is_supported': True}
# {'text': 'He has served at the University of San Andrés.', 'label': False}
# {'atom': 'His career began in the mid-90s.', 'is_supported': False}
# {'text': 'His career began in the mid-90s.', 'label': True}
# {'atom': 'The group was formed in the mid-90s.', 'is_supported': False}
# {'text': 'The group was formed in the mid-90s.', 'label': True}
# {'atom': 'He served as lead singer.', 'is_supported': False}
# {'text': 'He served as lead singer.', 'label': True}
# {'atom': 'He served as songwriter.', 'is_supported': False}
# {'text': 'He served as songwriter.', 'label': True}
# {'atom': 'He served as producer.', 'is_supported': False}
# {'text': 'He served as producer.', 'label': True}
# {'atom': 'He has written a number one single for Aventura.', 'is_supported': True}
# {'text': 'He has written a number one single for Aventura.', 'label': False}
# {'atom': 'He has produced a number one single for Aventura.', 'is_supported': True}
# {'text': 'He has produced a number one single for Aventura.', 'label': False}
# {'atom': 'Santos has produced solo material.', 'is_supported': False}
# {'text': 'Santos has produced solo material.', 'label': True}
# {'atom': 'The album was called Henry Santos.', 'is_supported': False}
# {'text': 'The album was called Henry Santos.', 'label': True}
# {'atom': 'He has collaborated with several other artists.', 'is_supported': False}
# {'text': 'He has collaborated with several other artists.', 'label': True}
# {'atom': 'He has collaborated with several producers.', 'is_supported': False}
# {'text': 'He has collaborated with several producers.', 'label': True}
# {'atom': 'He has collaborated with Don Omar.', 'is_supported': False}
# {'text': 'He has collaborated with Don Omar.', 'label': True}
# {'atom': 'Santos has won numerous awards.', 'is_supported': True}
# {'text': 'Santos has won numerous awards.', 'label': False}
# {'atom': 'Scientist is a Jamaican.', 'is_supported': True}
# {'text': 'Scientist is a Jamaican.', 'label': False}
# {'atom': 'Scientist is a dub musician.', 'is_supported': True}
# {'text': 'Scientist is a dub musician.', 'label': False}
# {'atom': 'He is well known for his innovative production techniques.', 'is_supported': False}
# {'text': 'He is well known for his innovative production techniques.', 'label': True}
# {'atom': 'He is well known for his production work with other artists.', 'is_supported': False}
# {'text': 'He is well known for his production work with other artists.', 'label': True}
# {'atom': 'King Tubby is an artist.', 'is_supported': True}
# {'text': 'King Tubby is an artist.', 'label': False}
# {'atom': 'Lee "Scratch" Perry is an artist.', 'is_supported': False}
# {'text': 'Lee "Scratch" Perry is an artist.', 'label': True}
# {'atom': 'He has been a major influence on the development of the dub genre.', 'is_supported': False}
# {'text': 'He has been a major influence on the development of the dub genre.', 'label': True}
# {'atom': 'Itote attended mission schools.', 'is_supported': False}
# {'text': 'Itote attended mission schools.', 'label': True}
# {'atom': 'Itote joined the British Army after attending school.', 'is_supported': False}
# {'text': 'Itote joined the British Army after attending school.', 'label': True}
# {'atom': 'Itote joined the Army in World War II.', 'is_supported': True}
# {'text': 'Itote joined the Army in World War II.', 'label': False}
# {'atom': 'He became a leader.', 'is_supported': False}
# {'text': 'He became a leader.', 'label': True}
# {'atom': 'He lead the Mau Mau rebellion.', 'is_supported': False}
# {'text': 'He lead the Mau Mau rebellion.', 'label': True}
# {'atom': "Kenya's independence was achieved in 1963.", 'is_supported': False}
# {'text': "Kenya's independence was achieved in 1963.", 'label': True}
# {'atom': 'Ramesses IV was the third Pharaoh.', 'is_supported': False}
# {'text': 'Ramesses IV was the third Pharaoh.', 'label': True}
# {'atom': 'He was known as a great builder.', 'is_supported': False}
# {'text': 'He was known as a great builder.', 'label': True}
# {'atom': 'He constructed temples.', 'is_supported': False}
# {'text': 'He constructed temples.', 'label': True}
# {'atom': 'His tomb is in the Valley of the Kings.', 'is_supported': False}
# {'text': 'His tomb is in the Valley of the Kings.', 'label': True}
# {'atom': 'He made his acting debut in a film.', 'is_supported': True}
# {'text': 'He made his acting debut in a film.', 'label': False}
# {'atom': 'The film was called City of God.', 'is_supported': True}
# {'text': 'The film was called City of God.', 'label': False}
# {'atom': 'City of God is a film.', 'is_supported': False}
# {'text': 'City of God is a film.', 'label': True}
# {'atom': 'City of God was released in 2002.', 'is_supported': False}
# {'text': 'City of God was released in 2002.', 'label': True}
# {'atom': 'Takeo Miki died in 1988.', 'is_supported': False}
# {'text': 'Takeo Miki died in 1988.', 'label': True}
# {'atom': 'He became a prominent figure in the Liberal Democratic Party.', 'is_supported': True}
# {'text': 'He became a prominent figure in the Liberal Democratic Party.', 'label': False}
# {'atom': 'He was elected to the House of Representatives.', 'is_supported': True}
# {'text': 'He was elected to the House of Representatives.', 'label': False}
# {'atom': 'He was elected to the House of Representatives in 1947.', 'is_supported': True}
# {'text': 'He was elected to the House of Representatives in 1947.', 'label': False}
# {'atom': 'He served in various cabinet positions.', 'is_supported': False}
# {'text': 'He served in various cabinet positions.', 'label': True}
# {'atom': 'He served as Prime Minister for two years.', 'is_supported': False}
# {'text': 'He served as Prime Minister for two years.', 'label': True}
# {'atom': 'He died in 1988.', 'is_supported': False}
# {'text': 'He died in 1988.', 'label': True}
# {'atom': 'He was born in Nagpur.', 'is_supported': True}
# {'text': 'He was born in Nagpur.', 'label': False}
# {'atom': 'Nagpur is in Maharashtra.', 'is_supported': True}
# {'text': 'Nagpur is in Maharashtra.', 'label': False}
# {'atom': 'His degree was in law.', 'is_supported': False}
# {'text': 'His degree was in law.', 'label': True}
# {'atom': 'He was elected in October 2015.', 'is_supported': True}
# {'text': 'He was elected in October 2015.', 'label': False}
# {'atom': 'He was re-elected for a second term.', 'is_supported': True}
# {'text': 'He was re-elected for a second term.', 'label': False}
# {'atom': 'He is known for his stance on the issue of corruption in cricket.', 'is_supported': False}
# {'text': 'He is known for his stance on the issue of corruption in cricket.', 'label': True}
# {'atom': 'His stance is strong.', 'is_supported': False}
# {'text': 'His stance is strong.', 'label': True}
# {'atom': 'He is known for his commitment to good governance.', 'is_supported': False}
# {'text': 'He is known for his commitment to good governance.', 'label': True}
# {'atom': 'He was released from prison.', 'is_supported': True}
# {'text': 'He was released from prison.', 'label': False}
# {'atom': 'She is best known for her work in the Tamil film industry.', 'is_supported': False}
# {'text': 'She is best known for her work in the Tamil film industry.', 'label': True}
# {'atom': 'She has worked in a number of successful films.', 'is_supported': False}
# {'text': 'She has worked in a number of successful films.', 'label': True}
# {'atom': 'She has won several awards.', 'is_supported': False}
# {'text': 'She has won several awards.', 'label': True}
# {'atom': 'She is a philanthropist.', 'is_supported': False}
# {'text': 'She is a philanthropist.', 'label': True}
# {'atom': 'She began her career in the 1960s.', 'is_supported': True}
# {'text': 'She began her career in the 1960s.', 'label': False}
# {'atom': 'In 1970 she created the Love is... comic strip.', 'is_supported': False}
# {'text': 'In 1970 she created the Love is... comic strip.', 'label': True}
# {'atom': 'The Love is... comic strip featured a romantic couple.', 'is_supported': False}
# {'text': 'The Love is... comic strip featured a romantic couple.', 'label': True}
# {'atom': 'He is a former World Surf League (WSL) World Championship Tour (CT) competitor.', 'is_supported': True}
# {'text': 'He is a former World Surf League (WSL) World Championship Tour (CT) competitor.', 'label': False}
# {'atom': 'Owen is known for his competitive success.', 'is_supported': False}
# {'text': 'Owen is known for his competitive success.', 'label': True}
# {'atom': 'He has won multiple events in Australia.', 'is_supported': False}
# {'text': 'He has won multiple events in Australia.', 'label': True}
# {'atom': 'He has achieved success in large-scale international events.', 'is_supported': False}
# {'text': 'He has achieved success in large-scale international events.', 'label': True}
# {'atom': 'She first rose to fame after joining a reality talent show.', 'is_supported': False}
# {'text': 'She first rose to fame after joining a reality talent show.', 'label': True}
# {'atom': 'The single was released after her stint in the show.', 'is_supported': True}
# {'text': 'The single was released after her stint in the show.', 'label': False}
# {'atom': 'She also starred in a film.', 'is_supported': False}
# {'text': 'She also starred in a film.', 'label': True}
# {'atom': 'She appeared in numerous television shows.', 'is_supported': False}
# {'text': 'She appeared in numerous television shows.', 'label': True}
# {'atom': "The show is called It's Showtime.", 'is_supported': True}
# {'text': "The show is called It's Showtime.", 'label': False}
# {'atom': 'He is a singer.', 'is_supported': False}
# {'text': 'He is a singer.', 'label': True}
# {'atom': 'He is a guitarist.', 'is_supported': False}
# {'text': 'He is a guitarist.', 'label': True}
# {'atom': 'He is the lead singer of The Living End.', 'is_supported': False}
# {'text': 'He is the lead singer of The Living End.', 'label': True}
# {'atom': 'He is the lead guitarist of The Living End.', 'is_supported': True}
# {'text': 'He is the lead guitarist of The Living End.', 'label': False}
# {'atom': 'He is the main songwriter of The Living End.', 'is_supported': True}
# {'text': 'He is the main songwriter of The Living End.', 'label': False}
# {'atom': 'He has been a part of a group since its formation.', 'is_supported': False}
# {'text': 'He has been a part of a group since its formation.', 'label': True}
# {'atom': 'Cheney has released eight studio albums with The Living End.', 'is_supported': False}
# {'text': 'Cheney has released eight studio albums with The Living End.', 'label': True}
# {'atom': 'The albums have charted in Australia.', 'is_supported': False}
# {'text': 'The albums have charted in Australia.', 'label': True}
# {'atom': 'He has collaborated with a variety of other artists.', 'is_supported': False}
# {'text': 'He has collaborated with a variety of other artists.', 'label': True}
# {'atom': 'Cheney has been recognised with numerous awards.', 'is_supported': False}
# {'text': 'Cheney has been recognised with numerous awards.', 'label': True}
# {'atom': 'Cheney has been recognised with multiple ARIA Awards.', 'is_supported': True}
# {'text': 'Cheney has been recognised with multiple ARIA Awards.', 'label': False}
# {'atom': 'He has released four studio albums.', 'is_supported': True}
# {'text': 'He has released four studio albums.', 'label': False}
# {'atom': 'He has released King.', 'is_supported': False}
# {'text': 'He has released King.', 'label': True}
# {'atom': 'King is an album.', 'is_supported': False}
# {'text': 'King is an album.', 'label': True}
# {'atom': 'He has released a number of mix tapes.', 'is_supported': False}
# {'text': 'He has released a number of mix tapes.', 'label': True}
# {'atom': 'He is known for his aggressive lyrical flow.', 'is_supported': False}
# {'text': 'He is known for his aggressive lyrical flow.', 'label': True}
# {'atom': 'He has collaborated with a number of hip hop acts.', 'is_supported': True}
# {'text': 'He has collaborated with a number of hip hop acts.', 'label': False}
# {'atom': 'The hip hop acts he has collaborated with are prominent.', 'is_supported': True}
# {'text': 'The hip hop acts he has collaborated with are prominent.', 'label': False}
# {'atom': 'He has appeared in numerous films.', 'is_supported': True}
# {'text': 'He has appeared in numerous films.', 'label': False}
# {'atom': 'South Pacific is a movie musical.', 'is_supported': False}
# {'text': 'South Pacific is a movie musical.', 'label': True}
# {'atom': 'She is best known for her performance in Les Girls.', 'is_supported': False}
# {'text': 'She is best known for her performance in Les Girls.', 'label': True}
# {'atom': 'Les Girls is a movie musical.', 'is_supported': False}
# {'text': 'Les Girls is a movie musical.', 'label': True}
# {'atom': 'Les Girls was released in 1957.', 'is_supported': False}
# {'text': 'Les Girls was released in 1957.', 'label': True}
# {'atom': 'Gaynor began her career as a chorus girl.', 'is_supported': True}
# {'text': 'Gaynor began her career as a chorus girl.', 'label': False}
# {'atom': 'She released several albums.', 'is_supported': True}
# {'text': 'She released several albums.', 'label': False}
# {'atom': 'She released Mitzi.', 'is_supported': False}
# {'text': 'She released Mitzi.', 'label': True}
# {'atom': 'He is best known for his successful negotiation.', 'is_supported': False}
# {'text': 'He is best known for his successful negotiation.', 'label': True}
# {'atom': 'Darrius Heyward-Bey played for seven seasons.', 'is_supported': True}
# {'text': 'Darrius Heyward-Bey played for seven seasons.', 'label': False}
# {'atom': 'Andrew Shue is an activist.', 'is_supported': True}
# {'text': 'Andrew Shue is an activist.', 'label': False}
# {'atom': 'Andrew Shue is best known for his role as Billy Campbell.', 'is_supported': False}
# ...
# {'atom': 'Bedroom floor is a single.', 'is_supported': False}
# {'text': 'Bedroom floor is a single.', 'label': True}
# {'atom': 'Payne is an ambassador for Global Citizen.', 'is_supported': True}
# {'text': 'Payne is an ambassador for Global Citizen.', 'label': False}
# {'atom': 'He won a Ligue 1 title in 2011.', 'is_supported': False}
# {'text': 'He won a Ligue 1 title in 2011.', 'label': True}
# {'atom': 'She is an active philanthropist.', 'is_supported': False}
# {'text': 'She is an active philanthropist.', 'label': True}
# {'atom': 'He is popularly dubbed "the phenomenon".', 'is_supported': False}
# {'text': 'He is popularly dubbed "the phenomenon".', 'label': True}
# {'atom': 'He began his career as a youth player.', 'is_supported': False}
# {'text': 'He began his career as a youth player.', 'label': True}
# {'atom': 'After playing for Cruzeiro, he joined PSV Eindhoven.', 'is_supported': False}
# {'text': 'After playing for Cruzeiro, he joined PSV Eindhoven.', 'label': True}
# {'atom': 'He moved to Real Madrid in 2002.', 'is_supported': False}
# {'text': 'He moved to Real Madrid in 2002.', 'label': True}
# {'atom': 'He has scored 62 goals.', 'is_supported': True}
# {'text': 'He has scored 62 goals.', 'label': False}
# {'atom': 'He was a part of the Brazilian team in the 1994 FIFA World Cup.', 'is_supported': False}
# {'text': 'He was a part of the Brazilian team in the 1994 FIFA World Cup.', 'label': True}
# {'atom': 'He was named FIFA World Player of the Year twice.', 'is_supported': False}
# {'text': 'He was named FIFA World Player of the Year twice.', 'label': True}
# {'atom': 'He became a businessman.', 'is_supported': False}
# {'text': 'He became a businessman.', 'label': True}
# {'atom': 'He became an investor.', 'is_supported': False}
# {'text': 'He became an investor.', 'label': True}
# {'atom': 'The Department of Huancavelica is in Peru.', 'is_supported': False}
# {'text': 'The Department of Huancavelica is in Peru.', 'label': True}
# {'atom': "Medina's father is Tiburelo Medina.", 'is_supported': False}
# {'text': "Medina's father is Tiburelo Medina.", 'label': True}
# {'atom': 'Her parents thought she had a tumor.', 'is_supported': True}
# {'text': 'Her parents thought she had a tumor.', 'label': False}
# {'atom': 'Her parents cited her development.', 'is_supported': True}
# {'text': 'Her parents cited her development.', 'label': False}
# {'atom': 'She was examined.', 'is_supported': False}
# {'text': 'She was examined.', 'label': True}
# {'atom': 'They determined she was pregnant.', 'is_supported': False}
# {'text': 'They determined she was pregnant.', 'label': True}
# {'atom': 'The baby weighed 2.7 kg at birth.', 'is_supported': False}
# {'text': 'The baby weighed 2.7 kg at birth.', 'label': True}
# {'atom': 'Tiffany Haddish is a writer.', 'is_supported': False}
# {'text': 'Tiffany Haddish is a writer.', 'label': True}
# {'atom': 'Tiffany Haddish is a producer.', 'is_supported': False}
# {'text': 'Tiffany Haddish is a producer.', 'label': True}
# {'atom': 'Def Comedy Jam is a show.', 'is_supported': False}
# {'text': 'Def Comedy Jam is a show.', 'label': True}
# {'atom': 'Chelsea Lately is a show.', 'is_supported': False}
# {'text': 'Chelsea Lately is a show.', 'label': True}
# {'atom': "Nobody's Fool is a film.", 'is_supported': False}
# {'text': "Nobody's Fool is a film.", 'label': True}
# {'atom': "Nobody's Fool was released in 2018.", 'is_supported': False}
# {'text': "Nobody's Fool was released in 2018.", 'label': True}
# {'atom': 'Tuca & Bertie premiered in 2019.', 'is_supported': False}
# {'text': 'Tuca & Bertie premiered in 2019.', 'label': True}
# {'atom': 'Haddish won the Emmy for a guest appearance.', 'is_supported': False}
# {'text': 'Haddish won the Emmy for a guest appearance.', 'label': True}
# {'atom': 'Her guest appearance was in 2017.', 'is_supported': False}
# {'text': 'Her guest appearance was in 2017.', 'label': True}
# {'atom': 'Mauro Emanuel Icardi plays for the Argentine national team.', 'is_supported': True}
# {'text': 'Mauro Emanuel Icardi plays for the Argentine national team.', 'label': False}
# {'atom': 'He began his career with a local club.', 'is_supported': False}
# {'text': 'He began his career with a local club.', 'label': True}
# {'atom': 'He had moved to Barcelona.', 'is_supported': False}
# {'text': 'He had moved to Barcelona.', 'label': True}
# {'atom': 'he signed in 2011.', 'is_supported': False}
# {'text': 'he signed in 2011.', 'label': True}
# {'atom': "He signed after two seasons in Barcelona's youth system.", 'is_supported': False}
# {'text': "He signed after two seasons in Barcelona's youth system.", 'label': True}
# {'atom': 'He has scored 124 goals for Inter Milan.', 'is_supported': False}
# {'text': 'He has scored 124 goals for Inter Milan.', 'label': True}
# {'atom': 'He has made 219 appearances for Inter Milan.', 'is_supported': False}
# {'text': 'He has made 219 appearances for Inter Milan.', 'label': True}
# {'atom': 'The caps were for Argentina.', 'is_supported': False}
# {'text': 'The caps were for Argentina.', 'label': True}
# {'atom': 'Carlos Santana is Mexican.', 'is_supported': False}
# {'text': 'Carlos Santana is Mexican.', 'label': True}
# {'atom': 'The band released an album in 1969.', 'is_supported': False}
# {'text': 'The band released an album in 1969.', 'label': True}
# {'atom': "The band's first album was called Santana.", 'is_supported': True}
# {'text': "The band's first album was called Santana.", 'label': False}
# {'atom': 'Santana received widespread critical acclaim.', 'is_supported': True}
# {'text': 'Santana received widespread critical acclaim.', 'label': False}
# {'atom': 'Santana has won 10 Grammy Awards.', 'is_supported': False}
# {'text': 'Santana has won 10 Grammy Awards.', 'label': True}
# {'atom': 'The Milagro Foundation helps underprivileged children.', 'is_supported': True}
# {'text': 'The Milagro Foundation helps underprivileged children.', 'label': False}
# {'atom': 'The Milagro Foundation helps at-risk children.', 'is_supported': True}
# {'text': 'The Milagro Foundation helps at-risk children.', 'label': False}
# {'atom': 'The Milagro Foundation helps children around the world.', 'is_supported': True}
# {'text': 'The Milagro Foundation helps children around the world.', 'label': False}
# {'atom': 'She began her career in theater.', 'is_supported': True}
# {'text': 'She began her career in theater.', 'label': False}
# {'atom': 'She has appeared in numerous films.', 'is_supported': False}
# {'text': 'She has appeared in numerous films.', 'label': True}
# {'atom': 'She has appeared in numerous television shows.', 'is_supported': False}
# {'text': 'She has appeared in numerous television shows.', 'label': True}
# {'atom': 'Her music career began with the release of her debut album.', 'is_supported': True}
# {'text': 'Her music career began with the release of her debut album.', 'label': False}
# {'atom': 'She has become a well-known figure.', 'is_supported': False}
# {'text': 'She has become a well-known figure.', 'label': True}
# {'atom': 'She is well-known in the Brazilian music scene.', 'is_supported': False}
# {'text': 'She is well-known in the Brazilian music scene.', 'label': True}
# {'atom': 'Mohamed Salah Ghaly is a professional footballer.', 'is_supported': False}
# {'text': 'Mohamed Salah Ghaly is a professional footballer.', 'label': True}
# {'atom': 'Mohamed Salah Ghaly plays as a forward.', 'is_supported': False}
# {'text': 'Mohamed Salah Ghaly plays as a forward.', 'label': True}
# {'atom': 'He moved to Chelsea in 2013.', 'is_supported': False}
# {'text': 'He moved to Chelsea in 2013.', 'label': True}
# {'atom': 'He won the Premier League in 2014–15.', 'is_supported': False}
# {'text': 'He won the Premier League in 2014–15.', 'label': True}
# {'atom': 'He moved to Roma in 2016.', 'is_supported': False}
# {'text': 'He moved to Roma in 2016.', 'label': True}
# {'atom': 'Salah is the all-time leading goalscorer for Egypt.', 'is_supported': False}
# {'text': 'Salah is the all-time leading goalscorer for Egypt.', 'label': True}
# {'atom': 'Jidenna Theodore Mobisson is a songwriter.', 'is_supported': True}
# {'text': 'Jidenna Theodore Mobisson is a songwriter.', 'label': False}
# {'atom': 'Jidenna is signed to Epic Records.', 'is_supported': True}
# {'text': 'Jidenna is signed to Epic Records.', 'label': False}
# {'atom': 'He is a three-weight world champion.', 'is_supported': True}
# {'text': 'He is a three-weight world champion.', 'label': False}
# {'atom': 'He is an athlete.', 'is_supported': True}
# {'text': 'He is an athlete.', 'label': False}
# {'atom': 'He is best known for his role as Billy.', 'is_supported': False}
# {'text': 'He is best known for his role as Billy.', 'label': True}
# {'atom': 'He played Billy in 2017.', 'is_supported': False}
# {'text': 'He played Billy in 2017.', 'label': True}
# {'atom': 'A Few Less Men was released in 2017.', 'is_supported': False}
# {'text': 'A Few Less Men was released in 2017.', 'label': True}
# {'atom': 'He has appeared in television series.', 'is_supported': False}
# {'text': 'He has appeared in television series.', 'label': True}
# {'atom': 'Teresa Palmer is a writer.', 'is_supported': False}
# {'text': 'Teresa Palmer is a writer.', 'label': True}
# {'atom': 'She has starred in Berlin Syndrome.', 'is_supported': False}
# {'text': 'She has starred in Berlin Syndrome.', 'label': True}
# {'atom': 'She has appeared in television shows.', 'is_supported': True}
# {'text': 'She has appeared in television shows.', 'label': False}
# {'atom': "He was appointed Australia's Ambassador.", 'is_supported': False}
# {'text': "He was appointed Australia's Ambassador.", 'label': True}
# {'atom': 'He is a passionate advocate.', 'is_supported': False}
# {'text': 'He is a passionate advocate.', 'label': True}
# {'atom': 'He is an author.', 'is_supported': False}
# {'text': 'He is an author.', 'label': True}
# {'atom': 'Rakhi Sawant appears in Kannada films.', 'is_supported': False}
# {'text': 'Rakhi Sawant appears in Kannada films.', 'label': True}
# {'atom': 'Rakhi was born in Mumbai.', 'is_supported': True}
# {'text': 'Rakhi was born in Mumbai.', 'label': False}
# {'atom': 'She is the daughter of Anand Sawant.', 'is_supported': False}
# {'text': 'She is the daughter of Anand Sawant.', 'label': True}
# {'atom': 'Rakhi has appeared in Jhalak Dikhla Jaa.', 'is_supported': False}
# {'text': 'Rakhi has appeared in Jhalak Dikhla Jaa.', 'label': True}
# {'atom': 'Rakhi has appeared in Nach Baliye.', 'is_supported': False}
# {'text': 'Rakhi has appeared in Nach Baliye.', 'label': True}
# {'atom': 'Rakhi has appeared in Ek Khiladi Ek Hasina.', 'is_supported': False}
# {'text': 'Rakhi has appeared in Ek Khiladi Ek Hasina.', 'label': True}
# {'atom': 'Kang Daniel is a dancer.', 'is_supported': True}
# {'text': 'Kang Daniel is a dancer.', 'label': False}
# {'atom': 'His solo debut was in July 2019.', 'is_supported': False}
# {'text': 'His solo debut was in July 2019.', 'label': True}
# {'atom': 'He first gained recognition in 2017.', 'is_supported': False}
# {'text': 'He first gained recognition in 2017.', 'label': True}
# {'atom': 'He first gained recognition after placing first in a show.', 'is_supported': False}
# {'text': 'He first gained recognition after placing first in a show.', 'label': True}
# {'atom': 'The show was a survival show.', 'is_supported': True}
# {'text': 'The show was a survival show.', 'label': False}
# {'atom': 'He has released multiple albums.', 'is_supported': False}
# {'text': 'He has released multiple albums.', 'label': True}
# {'atom': 'He has released collaborations with other artists.', 'is_supported': False}
# {'text': 'He has released collaborations with other artists.', 'label': True}
# {'atom': 'She has received one Filmfare Award.', 'is_supported': False}
# {'text': 'She has received one Filmfare Award.', 'label': True}
# {'atom': 'She is one of the most popular actresses in India.', 'is_supported': True}
# {'text': 'She is one of the most popular actresses in India.', 'label': False}
# {'atom': 'She has appeared in the since 2012.', 'is_supported': False}
# {'text': 'She has appeared in the since 2012.', 'label': True}
# {'atom': 'She was featured in their  list in 2018.', 'is_supported': False}
# {'text': 'She was featured in their  list in 2018.', 'label': True}
# {'atom': 'She has released numerous singles.', 'is_supported': False}
# {'text': 'She has released numerous singles.', 'label': True}
# {'atom': 'She has released "Palette".', 'is_supported': False}
# {'text': 'She has released "Palette".', 'label': True}
# {'atom': 'She has released "Love Poem".', 'is_supported': False}
# {'text': 'She has released "Love Poem".', 'label': True}
# {'atom': 'She has collaborated with numerous artists.', 'is_supported': False}
# {'text': 'She has collaborated with numerous artists.', 'label': True}
# {'atom': 'Suga is an artist.', 'is_supported': False}
# {'text': 'Suga is an artist.', 'label': True}
# {'atom': 'She has collaborated with Suga.', 'is_supported': False}
# {'text': 'She has collaborated with Suga.', 'label': True}
# {'atom': 'Suga is in BTS.', 'is_supported': False}
# {'text': 'Suga is in BTS.', 'label': True}
# {'atom': 'IU is multi-talented.', 'is_supported': False}
# {'text': 'IU is multi-talented.', 'label': True}
# {'atom': 'She won the Grand Prize at the Mnet Asian Music Awards.', 'is_supported': False}
# {'text': 'She won the Grand Prize at the Mnet Asian Music Awards.', 'label': True}
# {'atom': 'All In was released in 2003.', 'is_supported': False}
# {'text': 'All In was released in 2003.', 'label': True}
# {'atom': 'New Heart was released in 2007.', 'is_supported': False}
# {'text': 'New Heart was released in 2007.', 'label': True}
# {'atom': 'Protect the Boss was released in 2011.', 'is_supported': False}
# {'text': 'Protect the Boss was released in 2011.', 'label': True}
# {'atom': 'He is best known for his role in Secret.', 'is_supported': True}
# {'text': 'He is best known for his role in Secret.', 'label': False}
# {'atom': 'He has starred in films.', 'is_supported': False}
# {'text': 'He has starred in films.', 'label': True}
# {'atom': 'He is the first Korean actor to win the Grand Prize at all three of the major Korean award ceremonies.', 'is_supported': True}
# {'text': 'He is the first Korean actor to win the Grand Prize at all three of the major Korean award ceremonies.', 'label': False}
# {'atom': 'The MBC Drama Awards is a major Korean award ceremony.', 'is_supported': False}
# {'text': 'The MBC Drama Awards is a major Korean award ceremony.', 'label': True}
# {'atom': 'He is married to Lee Bo Young.', 'is_supported': False}
# {'text': 'He is married to Lee Bo Young.', 'label': True}
# {'atom': 'Lee Bo Young is an actress.', 'is_supported': False}
# {'text': 'Lee Bo Young is an actress.', 'label': True}
# {'atom': 'He has been married to Lee Bo Young since 2013.', 'is_supported': False}
# {'text': 'He has been married to Lee Bo Young since 2013.', 'label': True}
# {'atom': 'Two Cars, One Night was released in 2004.', 'is_supported': False}
# {'text': 'Two Cars, One Night was released in 2004.', 'label': True}
# {'atom': 'He directed Boy.', 'is_supported': False}
# {'text': 'He directed Boy.', 'label': True}
# {'atom': 'Boy is a film.', 'is_supported': False}
# {'text': 'Boy is a film.', 'label': True}
# {'atom': 'Boy was released in 2010.', 'is_supported': False}
# {'text': 'Boy was released in 2010.', 'label': True}
# {'atom': 'What We Do in the Shadows is a film.', 'is_supported': False}
# {'text': 'What We Do in the Shadows is a film.', 'label': True}
# {'atom': 'He directed Jojo Rabbit.', 'is_supported': False}
# {'text': 'He directed Jojo Rabbit.', 'label': True}
# {'atom': 'Jojo Rabbit is a film.', 'is_supported': False}
# {'text': 'Jojo Rabbit is a film.', 'label': True}
# {'atom': 'Jojo Rabbit was released in 2019.', 'is_supported': False}
# {'text': 'Jojo Rabbit was released in 2019.', 'label': True}
# {'atom': 'Boy is a film.', 'is_supported': False}
# {'text': 'Boy is a film.', 'label': True}
# {'atom': 'Boy was released in 2010.', 'is_supported': False}
# {'text': 'Boy was released in 2010.', 'label': True}
# {'atom': "Waititi's work is often characterized by its deadpan delivery.", 'is_supported': True}
# {'text': "Waititi's work is often characterized by its deadpan delivery.", 'label': False}

# %% [markdown]
# # Annotator Agreement

# %%
from sklearn.metrics import cohen_kappa_score, confusion_matrix, accuracy_score

# %%
y1 = [i["is_supported"] for i in llamas]
y2 = [i["label"] for i in human_evals]
cohen_kappa_score(y1, y2)
# Out:
# 0.6765188767596118

# %%
accuracy_score(y1,y2)
# Out:
# 0.8427845958527296

# %%
confusion_matrix(y2,y1)
# Out:
# array([[2420,  206],
#        [ 537, 1563]])
